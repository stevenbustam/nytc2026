# %%
from ugot import ugot  # UGOT robot SDK
from IPython.display import clear_output  # Jupyter display helpers
import time  # For sleep/timing between motor commands

# Create a robot instance and connect over the network.
got = ugot.UGOT()
got.initialize("192.168.88.1")  # <-- Check if this matches your robot's IP address

# Pre-load vision models onto the UGOT
# All models listed here will be available for the rest of the session.
got.load_models(
    ["color_recognition", "word_recognition", "line_recognition", "apriltag_qrcode"]
)

# Open UGOT camera for later image recognition
got.open_camera()
got.mechanical_joint_control(angle1=0, angle2=0, angle3=0, duration=500)

# got.mechanical_arms_restory()

# got.mechanical_joint_control(angle1=0, angle2=90, angle3=90, duration=500)
# got.mechanical_clamp_close()




# try:
#     while True:
#         # get_color_total_info() returns a list of detected color results.
#         # Index [0] gives the name of the most prominent color (e.g. "Red", "Green").
#         color = got.get_color_total_info()[0]

#         # Update the robot's display based on detected color.
#         if color == "Red":
#             got.screen_display_background(3) # Red background
#             got.mecanum_stop()
#         elif color == "Green":
#             got.screen_display_background(6) # Green background
#             got.mecanum_translate_speed(angle=0, speed=10)
#         else:
#             got.screen_display_background(0) # Black background

#         # Print current color, or a message if nothing is detected.
#         if color:
#             print(color)
#         else:
#             print("No color!")

#         # Clear console output so each refresh shows only the latest color.
#         clear_output(wait=True)

# except KeyboardInterrupt:
#     # Safely stop the robot's wheels if the cell is interrupted.
#     got.mecanum_stop()
#     print("Done")


def AP_centralization_approaching(distance=0.15, gap=20, fwd_spd=20, strafe_spd=20):
    
    """
    Drive toward a detected AprilTag, keeping it centered in the camera frame.

    Parameters:
        distance  (float): Stop when the tag is within this many meters (default 0.15 m).
        gap       (int):   Pixel tolerance around center (320 px) before strafing (default 20 px).
        fwd_spd   (int):   Forward drive speed percentage (default 10 cm/s).
        strafe_spd(int):   Left/right correction speed percentage (default 10 cm/s).
    """
    # Get an initial reading to confirm a tag is visible before entering the loop.
    AP_info = got.get_apriltag_total_info()

    if not AP_info:
        print("No Tag Detected")
        return

    while True:
        # Refresh tag data every iteration for responsive corrections.
        AP_info = got.get_apriltag_total_info()

        if not AP_info:
            got.mecanum_stop()
            break

        AP_x = AP_info[0][1] # Horizontal pixel position of the tag (0=left, 640=right)
        AP_distance = AP_info[0][6] # Estimated distance to the tag in meters

        if AP_x < 320 - gap:
            # Tag is to the LEFT of center — strafe left to re-align.
            # mecanum_move_xyz(x, y, z): x=strafe, y=forward, z=rotation
            got.mecanum_move_xyz(-strafe_spd, strafe_spd, 0)
        elif AP_x > 320 + gap:
            # Tag is to the RIGHT of center — strafe right to re-align.
            got.mecanum_move_xyz(strafe_spd, strafe_spd, 0)
        elif AP_distance > distance:
            # Tag is centered but still too far — drive straight forward.
            got.mecanum_move_xyz(0, fwd_spd, 0)
        else:
            # Tag is centered AND within target distance — stop and exit.
            got.mecanum_stop()
            print("It's too close, let's stop.")
            break
        time.sleep(0.1)

try:
    got.mechanical_arms_restory()
    tag = got.get_apriltag_total_info()
    if tag:
        AP_centralization_approaching(distance=0.26, gap=20, fwd_spd=20, strafe_spd=20)
        got.mechanical_clamp_release()
        got.mechanical_joint_control(angle1=10, angle2=0, angle3=0, duration=500)
        got.mechanical_joint_control(angle1=15, angle2=10, angle3=0, duration=500)
        got.mechanical_joint_control(angle1=10, angle2=10, angle3=-95, duration=500)
        time.sleep(1)
        got.mechanical_clamp_close()
    else:
        print("No Tag Visible")

except KeyboardInterrupt:
    # Safety stop if the cell is interrupted manually.
    got.mecanum_stop()
    print("Done")

got.mecanum_translate_speed_times(angle=0, speed=30, times=70, unit=1)
got.mechanical_clamp_release()
# Out:
# 192.168.88.1:50051
# Done
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# Cell In[155], line 123
#     119     # Safety stop if the cell is interrupted manually.
#     120     got.mecanum_stop()
#     121     print("Done")
#     122
# --> 123 got.mecanum_translate_speed_times(angle=0, speed=30, times=70, unit=1)
#     124 got.mechanical_clamp_release()
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\ugot\ugot.py:818, in UGOT.mecanum_translate_speed_times(self, angle, speed, times, unit)
#     816     self.MODEL.mecanum_move_control(linear_speed=speed, direction=angle, time=times)
#     817 elif unit == E_Model.Unit.mileage:
# --> 818     self.MODEL.mecanum_move_control(linear_speed=speed, direction=angle, mileage=times)
#     819 else:
#     820     self.__print_move_unit_m_error_msg(sys._getframe().f_code.co_name, unit)
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\ugot\src\model_client.py:63, in ModelClient.mecanum_move_control(self, linear_speed, direction, rotate_speed, time, mileage, target_angle, client_type)
#      60 def mecanum_move_control(self, linear_speed=0, direction=0, rotate_speed=0, time=0, mileage=0, target_angle=0,
#      61                            client_type=0):
# ---> 63     response = self.model_move_control(linear_speed, direction, rotate_speed, time, mileage, target_angle,
#      64                                         model_type=MODEL_TYPE_MECANUM, client_type=client_type)
#      65     return response
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\ugot\src\model_client.py:56, in ModelClient.model_move_control(self, linear_speed, direction, rotate_speed, time, mileage, target_angle, model_type, client_type)
#      53 input_data.params.mileage = mileage
#      54 input_data.params.target_angle = target_angle
# ---> 56 response = self.client.modelCommonControl(input_data)
#      57 return response
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:1159, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1147 def __call__(
#    1148     self,
#    1149     request: Any,
#    (...)   1154     compression: Optional[grpc.Compression] = None,
#    1155 ) -> Any:
#    1156     state, call = self._blocking(
#    1157         request, timeout, metadata, credentials, wait_for_ready, compression
#    1158     )
# -> 1159     return _end_unary_response_blocking(state, call, False, None)
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\grpc\_channel.py:990, in _end_unary_response_blocking(state, call, with_call, deadline)
#     988         return state.response, rendezvous
#     989     return state.response
# --> 990 raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "WSAGetOverlappedResult: Connection aborted (An established connection was aborted by the software in your host machine.
#  -- 10053)"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"WSAGetOverlappedResult: Connection aborted (An established connection was aborted by the software in your host machine.\r\n -- 10053)", grpc_status:14}"
# >
